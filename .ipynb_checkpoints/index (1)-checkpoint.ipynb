# %%
import pandas as pd

url = "https://github.com/Nat-sf/PC2/raw/refs/heads/main/HDI%20(1).xlsx"

# Leer el archivo Excel desde el enlace
df = pd.read_excel(url)

# Mostrar las 5 primeras filas
df.head()
# Out:
#        Back Table 1. Human Development Index and its components   \
# 0       NaN                                                NaN
# 1       NaN                                                NaN
# 2       NaN                                                NaN
# 3       NaN                                                NaN
# 4  HDI rank                                            Country
#
#                        Unnamed: 2  Unnamed: 3                Unnamed: 4  \
# 0                             NaN         NaN                       NaN
# 1                             NaN         NaN                      SDG3
# 2                             NaN         NaN                       NaN
# 3  Human Development Index (HDI)          NaN  Life expectancy at birth
# 4                           Value         NaN                   (years)
#
#   Unnamed: 5                   Unnamed: 6 Unnamed: 7               Unnamed: 8  \
# ...

# %%
# Otra forma: eliminar filas y volver a enumerarlas

# df = df.drop(index=range(0, 7))

# df = df.reset_index(drop=True)

# df.head()

# %%
# Para saltar las 7 primeras filas
df = pd.read_excel(url, skiprows=7)
df.head()
# Out:
#    Unnamed: 0 VERY HIGH HUMAN DEVELOPMENT Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0         1.0                 Switzerland      0.962         NaN     83.9872
# 1         2.0                      Norway      0.961         NaN     83.2339
# 2         3.0                     Iceland      0.959         NaN     82.6782
# 3         4.0      Hong Kong, China (SAR)      0.952         NaN     85.4734
# 4         5.0                   Australia      0.951         NaN     84.5265
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  Unnamed: 10  \
# 0        NaN  16.500299        NaN   13.85966        NaN  66933.00454
# 1        NaN    18.1852          c   13.00363        NaN  64660.10622
# 2        NaN  19.163059          c   13.76717        NaN  55782.04981
# 3          d   17.27817        NaN   12.22621        NaN   62606.8454
# 4        NaN   21.05459          c   12.72682        NaN  49238.43335
#
#   Unnamed: 11 Unnamed: 12  Unnamed: 13 Unnamed: 14
# ...

# %%
# Mantener las primeras 194 filas, se remueven las filas no deseadas
# se seleccionan las filas desde el inicio hasta la fila 194 y se asigna nuevamente a la df variable
df = df.iloc[:194]
df
# Out:
#      Unnamed: 0 VERY HIGH HUMAN DEVELOPMENT Unnamed: 2  Unnamed: 3  \
# 0           1.0                 Switzerland      0.962         NaN
# 1           2.0                      Norway      0.961         NaN
# 2           3.0                     Iceland      0.959         NaN
# 3           4.0      Hong Kong, China (SAR)      0.952         NaN
# 4           5.0                   Australia      0.951         NaN
# ..          ...                         ...        ...         ...
# 189       187.0                     Burundi      0.426         NaN
# 190       188.0    Central African Republic      0.404         NaN
# 191       189.0                       Niger        0.4         NaN
# 192       190.0                        Chad      0.394         NaN
# 193       191.0                 South Sudan      0.385         NaN
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0       83.9872        NaN  16.500299        NaN   13.85966        NaN
# ...

# %%
# Se remueven las columnas con data no necesaria

df = df.drop(columns=['Unnamed: 0', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7', 'Unnamed: 9', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14'])
df.head()
# Out:
#   VERY HIGH HUMAN DEVELOPMENT Unnamed: 2  Unnamed: 4 Unnamed: 6 Unnamed: 8  \
# 0                 Switzerland      0.962     83.9872  16.500299   13.85966
# 1                      Norway      0.961     83.2339    18.1852   13.00363
# 2                     Iceland      0.959     82.6782  19.163059   13.76717
# 3      Hong Kong, China (SAR)      0.952     85.4734   17.27817   12.22621
# 4                   Australia      0.951     84.5265   21.05459   12.72682
#
#    Unnamed: 10
# 0  66933.00454
# 1  64660.10622
# 2  55782.04981
# 3   62606.8454
# 4  49238.43335

# %%
# Se cambian los nombres de las columnas

df.columns = ["Country", "Human_Development_Index", "Life_expectency_at_birth", "Expected_years_of_schooling", "Mean_years_of_schooling", "Gross_national_income_per_capita"]
df.head()
# Out:
#                   Country Human_Development_Index  Life_expectency_at_birth  \
# 0             Switzerland                   0.962                   83.9872
# 1                  Norway                   0.961                   83.2339
# 2                 Iceland                   0.959                   82.6782
# 3  Hong Kong, China (SAR)                   0.952                   85.4734
# 4               Australia                   0.951                   84.5265
#
#   Expected_years_of_schooling Mean_years_of_schooling  \
# 0                   16.500299                13.85966
# 1                     18.1852                13.00363
# 2                   19.163059                13.76717
# 3                    17.27817                12.22621
# 4                    21.05459                12.72682
#
#   Gross_national_income_per_capita
# 0                      66933.00454
# 1                      64660.10622
# 2                      55782.04981
# 3                       62606.8454
# ...

# %%
# espacios vacios

df[df.isnull().any(axis=1)]
# Out:
#                       Country Human_Development_Index  \
# 66     HIGH HUMAN DEVELOPMENT                     NaN
# 116  MEDIUM HUMAN DEVELOPMENT                     NaN
# 161     LOW HUMAN DEVELOPMENT                     NaN
#
#      Life_expectency_at_birth Expected_years_of_schooling  \
# 66                        NaN                         NaN
# 116                       NaN                         NaN
# 161                       NaN                         NaN
#
#     Mean_years_of_schooling Gross_national_income_per_capita
# 66                      NaN                              NaN
# 116                     NaN                              NaN
# 161                     NaN                              NaN

# %%
# eliminar espacios vacios

df=df.dropna(axis="rows", how="any", ignore_index=True)
df
# Out:
#                       Country Human_Development_Index  \
# 0                 Switzerland                   0.962
# 1                      Norway                   0.961
# 2                     Iceland                   0.959
# 3      Hong Kong, China (SAR)                   0.952
# 4                   Australia                   0.951
# ..                        ...                     ...
# 186                   Burundi                   0.426
# 187  Central African Republic                   0.404
# 188                     Niger                     0.4
# 189                      Chad                   0.394
# 190               South Sudan                   0.385
#
#      Life_expectency_at_birth Expected_years_of_schooling  \
# 0                     83.9872                   16.500299
# 1                     83.2339                     18.1852
# 2                     82.6782                   19.163059
# 3                     85.4734                    17.27817
# ...

# %%
# espacios vacios

df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Country, Human_Development_Index, Life_expectency_at_birth, Expected_years_of_schooling, Mean_years_of_schooling, Gross_national_income_per_capita]
# Index: []

# %%
# Verificar el tipo de dato que tiene cada columna del DataFrame

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           191 non-null    object
#  1   Human_Development_Index           191 non-null    object
#  2   Life_expectency_at_birth          191 non-null    float64
#  3   Expected_years_of_schooling       191 non-null    object
#  4   Mean_years_of_schooling           191 non-null    object
#  5   Gross_national_income_per_capita  191 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 9.1+ KB

# %%
# Para cambiar el tipo de dato

columnas_a_convertir=['Life_expectency_at_birth','Expected_years_of_schooling','Mean_years_of_schooling','Gross_national_income_per_capita']

# Se crea un bucle para iterar a través de cada nombre de columna en la lista, luego se convierten los números
# errors='coerce'Gestiona posibles errores durante la conversión.
for col in columnas_a_convertir:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           191 non-null    object
#  1   Human_Development_Index           191 non-null    object
#  2   Life_expectency_at_birth          191 non-null    float64
#  3   Expected_years_of_schooling       191 non-null    float64
#  4   Mean_years_of_schooling           191 non-null    float64
#  5   Gross_national_income_per_capita  191 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 9.1+ KB

# %%
#Redondeo de valores

un_decimal=['Life_expectency_at_birth','Expected_years_of_schooling','Mean_years_of_schooling']
dos_decimales=['Gross_national_income_per_capita']

df[un_decimal] = df[un_decimal].round(1)
df[dos_decimales]=df[dos_decimales].round(2)

df.head()
# Out:
#                   Country Human_Development_Index  Life_expectency_at_birth  \
# 0             Switzerland                   0.962                      84.0
# 1                  Norway                   0.961                      83.2
# 2                 Iceland                   0.959                      82.7
# 3  Hong Kong, China (SAR)                   0.952                      85.5
# 4               Australia                   0.951                      84.5
#
#    Expected_years_of_schooling  Mean_years_of_schooling  \
# 0                         16.5                     13.9
# 1                         18.2                     13.0
# 2                         19.2                     13.8
# 3                         17.3                     12.2
# 4                         21.1                     12.7
#
#    Gross_national_income_per_capita
# 0                          66933.00
# 1                          64660.11
# 2                          55782.05
# ...

# %%
# Clasificar en categorías según el HDI

# Definir los bins(límites de las categorías) y las etiquetas
bins = [0, 0.549, 0.699, 0.799, 1.0]
labels = ["LOW HUMAN DEVELOPMENT", "MEDIUM HUMAN DEVELOPMENT", "HIGH HUMAN DEVELOPMENT", "VERY HIGH HUMAN DEVELOPMENT"]

# Crear la nueva columna 'category'
df["Category"] = pd.cut(df["Human_Development_Index"], bins=bins, labels=labels)

df.head()
# Out:
#                   Country Human_Development_Index  Life_expectency_at_birth  \
# 0             Switzerland                   0.962                      84.0
# 1                  Norway                   0.961                      83.2
# 2                 Iceland                   0.959                      82.7
# 3  Hong Kong, China (SAR)                   0.952                      85.5
# 4               Australia                   0.951                      84.5
#
#    Expected_years_of_schooling  Mean_years_of_schooling  \
# 0                         16.5                     13.9
# 1                         18.2                     13.0
# 2                         19.2                     13.8
# 3                         17.3                     12.2
# 4                         21.1                     12.7
#
#    Gross_national_income_per_capita                     Category
# 0                          66933.00  VERY HIGH HUMAN DEVELOPMENT
# ...
